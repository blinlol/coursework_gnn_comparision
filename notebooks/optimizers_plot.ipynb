# %%
import pandas
import seaborn as sns
import matplotlib.pyplot as plt 

optimizers = [
    "adadelta",
    "adagrad",
    "adam",
    "adamax",
    "adamw",
    "asgd",
    "lbfgs",
    "nadam",
    "radam",
    "rmsprop",
    "rprop",
    "sgd",
    "sparseadam"
]

datasets = [
    "Cora",
    "BZR"
]

# %%
data = None
for opt in optimizers:
    df = pandas.read_csv(f"results_{opt}.csv", index_col='index')
    df['optimizer'] = opt
    data = pandas.concat([data, df], axis=0)
display(data)
df.index.nunique()
# Out:
#       dataset     layer   K  aggr  layers_number  epochs_number  \
# index
# 0           0         0 NaN     0              0              0
# 1        Cora   GCNConv NaN   add              1            170
# 2        Cora   GCNConv NaN   add              1            170
# 3        Cora   GCNConv NaN   add              1            170
# 4        Cora   GCNConv NaN   add              1            170
# ...       ...       ...  ..   ...            ...            ...
# 206       BZR  SAGEConv NaN  mean              4           2000
# 207       BZR  SAGEConv NaN  mean              4           2000
# 208       BZR  SAGEConv NaN  mean              4           2000
# 209       BZR  SAGEConv NaN  mean              4           2000
# 210       BZR  SAGEConv NaN  mean              4           2000
#
#        training_time  train_accuracy  train_F1  test_accuracy   test_F1  \
# index
# 0           3.494345        0.898430  0.889903       0.848708  0.832291
# ...

# %%
x = 'test_accuracy'
# x = 'training_time'
y = 'layer'
hue = 'layers_number'
figsize = (8, 4)
for dataset in datasets:
    for opt in optimizers:
        d = data.loc[(data.dataset == dataset) & (data.optimizer == opt)]
        plt.subplots(figsize=figsize)
        plt.title(dataset + ", " + opt)
        sns.boxplot(
            d,
            x=x,
            y=y,
            hue=hue,
            legend=True,
            gap=.2,
            width=0.5
        )

        sns.stripplot(
            d, 
            x=x, 
            y=y, 
            hue=hue, 
            dodge=True, 
            jitter=True,
            palette="pastel"
        )
# Out:
# /tmp/ipykernel_1852111/1480242700.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.subplots(figsize=figsize)

# %%
# x = 'test_accuracy'
x = 'training_time'
y = 'layer'
hue = 'layers_number'
figsize = (8, 4)
for dataset in datasets:
    for opt in optimizers:
        d = data.loc[(data.dataset == dataset) & (data.optimizer == opt)]
        plt.subplots(figsize=figsize)
        plt.title(dataset + ", " + opt)
        sns.boxplot(
            d,
            x=x,
            y=y,
            hue=hue,
            legend=True,
            gap=.2,
            width=0.5
        )

        sns.stripplot(
            d, 
            x=x, 
            y=y, 
            hue=hue, 
            dodge=True, 
            jitter=True,
            palette="pastel"
        )
# Out:
# /tmp/ipykernel_1852111/1823982444.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.subplots(figsize=figsize)
